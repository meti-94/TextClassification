# %% [markdown]
# <a href="https://colab.research.google.com/github/meti-94/TextClassification/blob/main/SingleStockTrading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git -q
# Out:
#      |████████████████████████████████| 234 kB 6.4 MB/s
#      |████████████████████████████████| 176 kB 46.3 MB/s
#      |████████████████████████████████| 57.6 MB 1.2 MB/s
#      |████████████████████████████████| 1.8 MB 40.2 MB/s
#      |████████████████████████████████| 124 kB 45.1 MB/s
#      |████████████████████████████████| 147 kB 31.2 MB/s
#      |████████████████████████████████| 45 kB 3.4 MB/s
#      |████████████████████████████████| 2.4 MB 42.7 MB/s
#      |████████████████████████████████| 153 kB 49.0 MB/s
#      |████████████████████████████████| 195 kB 48.5 MB/s
#      |████████████████████████████████| 90.8 MB 283 bytes/s
#      |████████████████████████████████| 448 kB 49.8 MB/s
#      |████████████████████████████████| 52 kB 1.3 MB/s
#      |████████████████████████████████| 1.1 MB 36.4 MB/s
#      |████████████████████████████████| 3.6 MB 28.0 MB/s
#      |████████████████████████████████| 271 kB 53.8 MB/s
#      |████████████████████████████████| 94 kB 3.3 MB/s
#      |████████████████████████████████| 291 kB 53.2 MB/s
#      |████████████████████████████████| 144 kB 51.0 MB/s
#      |████████████████████████████████| 103 kB 46.2 MB/s
#      |████████████████████████████████| 636 kB 53.0 MB/s
#      |████████████████████████████████| 273 kB 53.0 MB/s
#      |████████████████████████████████| 53 kB 1.9 MB/s
#      |████████████████████████████████| 43 kB 1.6 MB/s
#      |████████████████████████████████| 40 kB 5.1 MB/s
#      |████████████████████████████████| 361 kB 50.2 MB/s
#      |████████████████████████████████| 43 kB 2.0 MB/s
#      |████████████████████████████████| 49 kB 5.7 MB/s
#      |████████████████████████████████| 98 kB 7.7 MB/s
#      |████████████████████████████████| 6.5 MB 35.3 MB/s
#      |████████████████████████████████| 596 kB 37.2 MB/s
#      |████████████████████████████████| 461 kB 50.5 MB/s
#      |████████████████████████████████| 173 kB 50.5 MB/s
#      |████████████████████████████████| 201 kB 48.9 MB/s
#      |████████████████████████████████| 82 kB 249 kB/s
#      |████████████████████████████████| 65 kB 3.5 MB/s
#      |████████████████████████████████| 128 kB 46.6 MB/s
#      |████████████████████████████████| 3.0 MB 29.0 MB/s
#      |████████████████████████████████| 85 kB 3.7 MB/s
#      |████████████████████████████████| 58 kB 4.9 MB/s
#      |████████████████████████████████| 2.8 MB 50.8 MB/s
#      |████████████████████████████████| 3.0 MB 34.0 MB/s
#      |████████████████████████████████| 6.4 MB 30.8 MB/s
#      |████████████████████████████████| 63 kB 1.7 MB/s
# WARNING: The candidate selected for download or install is a yanked version: 'atari-py' candidate (version 0.2.6 at https://files.pythonhosted.org/packages/8f/ba/1d22e9d2f332f07aaa57041f5dd569c2cb40a92bd6374a0b743ec3dfae97/atari_py-0.2.6-cp37-cp37m-manylinux1_x86_64.whl#sha256=d9e2c25d39783867c2f29d1dd9d3a659fc56036456d07dc9efe8bd7bb31a07d7 (from https://pypi.org/simple/atari-py/))
# Reason for being yanked: re-release with new wheels
#   Building wheel for finrl (setup.py) ... done
#   Building wheel for elegantrl (setup.py) ... done
#   Building wheel for pyfolio (setup.py) ... done
#   Building wheel for empyrical (setup.py) ... done
#   Building wheel for exchange-calendars (setup.py) ... done
#   Building wheel for gputil (setup.py) ... done
#   Building wheel for thriftpy2 (setup.py) ... done
#   Building wheel for gpustat (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.

# %%
from finrl.apps import config
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
from datetime import datetime

# %matplotlib inline
from finrl.finrl_meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.finrl_meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.finrl_meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.drl_agents.stablebaselines3.models import DRLAgent
from finrl.finrl_meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %%
def read_data(path):
    hist = pd.read_csv(path, parse_dates=True)
    hist = hist[hist.Timestamp>=1388521800]
    hist['date'] = hist['Timestamp'].apply(lambda item:datetime.fromtimestamp(item))
    hist.set_index('date', inplace=True)
    hist.dropna(inplace=True)
    return hist

def resampling(hist, timeframe='1min'):
    ohlc = {
        'Open': 'first',
        'High': 'max',
        'Low': 'min',
        'Close': 'last',
        'Volume_(BTC)':'sum'
    }
    df = hist.resample(timeframe, origin='end_day').apply(ohlc)
    df.dropna(inplace=True)
    df.reset_index(inplace=True)
    df.rename(columns={'Open':'open', 'High':'high', 'Close':'close', 'Low':'low', 'Volume_(BTC)':'volume'}, inplace=True)
    df['date'] = df['date'].astype(str)
    df['tic'] = ['BTC' for _ in range(len(df))]
    df['day'] = [i%5 for i in range(len(df))]
    return df   
hist = read_data('/content/drive/MyDrive/kaggle_dataset/bitstampUSD_1-min_data_2012-01-01_to_2021-03-31.csv')
hist = hist['2014-01-01' :'2021-03-30']
hist = resampling(hist, timeframe='D')
df = hist

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = config.TECHNICAL_INDICATORS_LIST,
                    use_vix=True,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (1823, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.sort_values(['date','tic'],ignore_index=True).head(10)
# Out:
#          date  tic    open  ...  close_60_sma    vix  turbulence
# 0  2014-01-02  BTC  732.01  ...    743.450000  14.23         0.0
# 1  2014-01-03  BTC  751.88  ...    757.030000  13.76         0.0
# 2  2014-01-06  BTC  828.83  ...    802.386667  13.55         0.0
# 3  2014-01-07  BTC  905.23  ...    818.554286  12.92         0.0
# 4  2014-01-08  BTC  915.56  ...    813.735000  12.87         0.0
# 5  2014-01-09  BTC  784.50  ...    814.870000  12.89         0.0
# 6  2014-01-10  BTC  823.95  ...    815.859000  12.14         0.0
# 7  2014-01-13  BTC  894.70  ...    826.517692  13.28         0.0
# 8  2014-01-14  BTC  841.52  ...    826.337857  12.28         0.0
# 9  2014-01-15  BTC  824.00  ...    825.648000  12.28         0.0
#
# [10 rows x 18 columns]

# %%
processed_full.sort_values(['date','tic'],ignore_index=True).tail(10)
# Out:
#             date  tic      open  ...  close_60_sma        vix  turbulence
# 1810  2021-03-17  BTC  55413.23  ...  44871.618000  19.230000    0.207861
# 1811  2021-03-18  BTC  57079.16  ...  45261.045167  21.580000    0.330618
# 1812  2021-03-19  BTC  59235.60  ...  45621.242667  20.950001    0.748917
# 1813  2021-03-22  BTC  58038.65  ...  46711.766833  18.879999    0.070404
# 1814  2021-03-23  BTC  57393.65  ...  47105.283833  20.299999    2.076739
# 1815  2021-03-24  BTC  54249.05  ...  47461.071500  21.200001    0.053881
# 1816  2021-03-25  BTC  54267.89  ...  47800.005833  19.809999    0.991900
# 1817  2021-03-26  BTC  52291.72  ...  48118.446000  18.860001    0.401307
# 1818  2021-03-29  BTC  55946.79  ...  49316.047833  20.740000    3.051882
# 1819  2021-03-30  BTC  55822.98  ...  49719.447000  19.610001    0.290028
#
# [10 rows x 18 columns]

# %%
train = data_split(processed_full, '2014-01-01','2019-12-30')
trade = data_split(processed_full, '2019-12-30','2021-03-30')
print(len(train))
print(len(trade))
# Out:
# 1505
# 314

# %%
train.tail()
# Out:
#             date  tic     open  ...  close_60_sma    vix  turbulence
# 1500  2019-12-20  BTC  7312.33  ...   8056.563333  12.51    0.325071
# 1501  2019-12-23  BTC  7136.01  ...   8026.295500  12.61    1.264039
# 1502  2019-12-24  BTC  7543.27  ...   8024.343000  12.67    0.527695
# 1503  2019-12-26  BTC  7255.55  ...   7965.316333  12.65    0.230259
# 1504  2019-12-27  BTC  7189.82  ...   7925.613000  13.43    0.007648
#
# [5 rows x 18 columns]

# %%
train.head()
# Out:
#          date  tic    open  ...  close_60_sma    vix  turbulence
# 0  2014-01-02  BTC  732.01  ...    743.450000  14.23         0.0
# 1  2014-01-03  BTC  751.88  ...    757.030000  13.76         0.0
# 2  2014-01-06  BTC  828.83  ...    802.386667  13.55         0.0
# 3  2014-01-07  BTC  905.23  ...    818.554286  12.92         0.0
# 4  2014-01-08  BTC  915.56  ...    813.735000  12.87         0.0
#
# [5 rows x 18 columns]

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(config.TECHNICAL_INDICATORS_LIST)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 11

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": config.TECHNICAL_INDICATORS_LIST, 
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4
    
}

e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()

# %%
agent = DRLAgent(env = env_train)

# %%
model_a2c = agent.get_model("a2c")
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000)
# Out:
# --------------------------------------
# | time/                 |            |
# |    fps                | 179        |
# |    iterations         | 100        |
# |    time_elapsed       | 2          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -1.45      |
# |    explained_variance | -1.05      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -7.41      |
# |    reward             | -0.9308806 |
# |    std                | 1.03       |
# |    value_loss         | 15.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 211       |
# |    iterations         | 200       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -1.45     |
# |    explained_variance | 2.98e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 645       |
# |    reward             | -260.4218 |
# |    std                | 1.03      |
# |    value_loss         | 1.9e+05   |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 224        |
# |    iterations         | 300        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -1.44      |
# |    explained_variance | -0.000896  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -32.1      |
# |    reward             | -24.930298 |
# |    std                | 1.02       |
# |    value_loss         | 774        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 231       |
# |    iterations         | 400       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | -0.6      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 2.26      |
# |    reward             | -0.087962 |
# |    std                | 1.02      |
# |    value_loss         | 3.9       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 500      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1.45    |
# |    explained_variance | 0.0143   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 154      |
# |    reward             | 104.8985 |
# |    std                | 1.04     |
# |    value_loss         | 1.09e+04 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 239       |
# |    iterations         | 600       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | 0.00063   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 2.05      |
# |    reward             | -3.903207 |
# |    std                | 1.02      |
# |    value_loss         | 19.4      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 700      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0.395    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 2.47     |
# |    reward             | 0.895491 |
# |    std                | 1.01     |
# |    value_loss         | 2.85     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 245        |
# |    iterations         | 800        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -1.43      |
# |    explained_variance | 2.98e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 78.1       |
# |    reward             | -72.760445 |
# |    std                | 1.01       |
# |    value_loss         | 3.34e+03   |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 900      |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | -0.00329 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.218   |
# |    reward             | 8.455092 |
# |    std                | 1.01     |
# |    value_loss         | 312      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 1000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0.225    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.356    |
# |    reward             | 0.86112  |
# |    std                | 1.01     |
# |    value_loss         | 0.638    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 1100     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0.00647  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 45.5     |
# |    reward             | 45.37988 |
# |    std                | 1        |
# |    value_loss         | 1.46e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 1200      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -1.42     |
# |    explained_variance | -0.00383  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -16.2     |
# |    reward             | 11.193056 |
# |    std                | 1         |
# |    value_loss         | 325       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 250        |
# |    iterations         | 1300       |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -1.43      |
# |    explained_variance | -0.601     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -0.875     |
# |    reward             | -0.7357297 |
# |    std                | 1.01       |
# |    value_loss         | 0.425      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 251       |
# |    iterations         | 1400      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | -0.01     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 107       |
# |    reward             | 57.658855 |
# |    std                | 1.02      |
# |    value_loss         | 3.86e+03  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 251        |
# |    iterations         | 1500       |
# |    time_elapsed       | 29         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -1.43      |
# |    explained_variance | -0.00141   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | -16.7      |
# |    reward             | -1.8330387 |
# |    std                | 1.01       |
# |    value_loss         | 202        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 251       |
# |    iterations         | 1600      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | -0.0597   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -1.25     |
# |    reward             | -0.056664 |
# |    std                | 1.02      |
# |    value_loss         | 2.97      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 252       |
# |    iterations         | 1700      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -1.78     |
# |    reward             | 29.726133 |
# |    std                | 1.02      |
# |    value_loss         | 76.5      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 253        |
# |    iterations         | 1800       |
# |    time_elapsed       | 35         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -1.44      |
# |    explained_variance | 0.00266    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 11.1       |
# |    reward             | -3.4013307 |
# |    std                | 1.02       |
# |    value_loss         | 77.4       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 1900     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0.0339   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.78    |
# |    reward             | 0.839536 |
# |    std                | 1.01     |
# |    value_loss         | 3.36     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 253        |
# |    iterations         | 2000       |
# |    time_elapsed       | 39         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -1.44      |
# |    explained_variance | 0.0193     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 85.3       |
# |    reward             | -13.295815 |
# |    std                | 1.02       |
# |    value_loss         | 2.87e+03   |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 2100     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | -0.00661 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 93.3     |
# |    reward             | 1.949985 |
# |    std                | 1.01     |
# |    value_loss         | 7.2e+03  |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 254        |
# |    iterations         | 2200       |
# |    time_elapsed       | 43         |
# |    total_timesteps    | 11000      |
# | train/                |            |
# |    entropy_loss       | -1.43      |
# |    explained_variance | -0.13      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2199       |
# |    policy_loss        | 3.03       |
# |    reward             | 0.32602206 |
# |    std                | 1.01       |
# |    value_loss         | 4.72       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 2300     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0.0143   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 4.69     |
# |    reward             | 7.406096 |
# |    std                | 1.01     |
# |    value_loss         | 42.7     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 254       |
# |    iterations         | 2400      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -1.42     |
# |    explained_variance | -0.0142   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -27.8     |
# |    reward             | -8.667115 |
# |    std                | 0.997     |
# |    value_loss         | 279       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 254       |
# |    iterations         | 2500      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -1.41     |
# |    explained_variance | -0.125    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | 0.697     |
# |    reward             | 1.4591541 |
# |    std                | 0.995     |
# |    value_loss         | 0.383     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 2600     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | -0.00176 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 3.35     |
# |    reward             | 5.062384 |
# |    std                | 0.983    |
# |    value_loss         | 22.2     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 255        |
# |    iterations         | 2700       |
# |    time_elapsed       | 52         |
# |    total_timesteps    | 13500      |
# | train/                |            |
# |    entropy_loss       | -1.4       |
# |    explained_variance | 0.0357     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2699       |
# |    policy_loss        | -10.2      |
# |    reward             | -12.100294 |
# |    std                | 0.98       |
# |    value_loss         | 131        |
# --------------------------------------
# day: 1504, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 2008565.52
# total_reward: 1008565.52
# total_cost: 350043.46
# total_trades: 1502
# Sharpe: 0.558
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 255        |
# |    iterations         | 2800       |
# |    time_elapsed       | 54         |
# |    total_timesteps    | 14000      |
# | train/                |            |
# |    entropy_loss       | -1.39      |
# |    explained_variance | -0.15      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2799       |
# |    policy_loss        | 1.84       |
# |    reward             | 0.39277175 |
# |    std                | 0.973      |
# |    value_loss         | 1.96       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 2900     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | -0.00246 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 138      |
# |    reward             | 14.00086 |
# |    std                | 0.983    |
# |    value_loss         | 8.93e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 255       |
# |    iterations         | 3000      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -1.4      |
# |    explained_variance | 0.00673   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | 53.9      |
# |    reward             | -17.62085 |
# |    std                | 0.98      |
# |    value_loss         | 2.6e+03   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 3100     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.154    |
# |    reward             | 0.50652  |
# |    std                | 0.966    |
# |    value_loss         | 0.163    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 3200     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -0.042   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.784    |
# |    reward             | 77.91455 |
# |    std                | 0.968    |
# |    value_loss         | 111      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 3300      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -1.39     |
# |    explained_variance | 0.0235    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | 26.5      |
# |    reward             | 54.276913 |
# |    std                | 0.974     |
# |    value_loss         | 809       |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 256         |
# |    iterations         | 3400        |
# |    time_elapsed       | 66          |
# |    total_timesteps    | 17000       |
# | train/                |             |
# |    entropy_loss       | -1.39       |
# |    explained_variance | -3.27       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3399        |
# |    policy_loss        | 0.237       |
# |    reward             | -0.24671566 |
# |    std                | 0.967       |
# |    value_loss         | 0.138       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 256        |
# |    iterations         | 3500       |
# |    time_elapsed       | 68         |
# |    total_timesteps    | 17500      |
# | train/                |            |
# |    entropy_loss       | -1.37      |
# |    explained_variance | -0.0109    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3499       |
# |    policy_loss        | 8.28       |
# |    reward             | 0.09294488 |
# |    std                | 0.953      |
# |    value_loss         | 99.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 3600      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -1.37     |
# |    explained_variance | 0.00683   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -55.9     |
# |    reward             | 2.1035333 |
# |    std                | 0.952     |
# |    value_loss         | 1.28e+03  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 3700     |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.22     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.287    |
# |    reward             | 0.256334 |
# |    std                | 0.948    |
# |    value_loss         | 0.136    |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 256        |
# |    iterations         | 3800       |
# |    time_elapsed       | 74         |
# |    total_timesteps    | 19000      |
# | train/                |            |
# |    entropy_loss       | -1.37      |
# |    explained_variance | 0.00566    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3799       |
# |    policy_loss        | -10.6      |
# |    reward             | -2.3395107 |
# |    std                | 0.955      |
# |    value_loss         | 1.14e+03   |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 256        |
# |    iterations         | 3900       |
# |    time_elapsed       | 75         |
# |    total_timesteps    | 19500      |
# | train/                |            |
# |    entropy_loss       | -1.38      |
# |    explained_variance | 0.0685     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3899       |
# |    policy_loss        | -31.4      |
# |    reward             | -13.602954 |
# |    std                | 0.958      |
# |    value_loss         | 269        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 256        |
# |    iterations         | 4000       |
# |    time_elapsed       | 77         |
# |    total_timesteps    | 20000      |
# | train/                |            |
# |    entropy_loss       | -1.38      |
# |    explained_variance | -7.24      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3999       |
# |    policy_loss        | -0.204     |
# |    reward             | 0.26768935 |
# |    std                | 0.961      |
# |    value_loss         | 0.0422     |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 4100      |
# |    time_elapsed       | 79        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -1.36     |
# |    explained_variance | -0.000707 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -62.4     |
# |    reward             | -7.215438 |
# |    std                | 0.945     |
# |    value_loss         | 1.36e+03  |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 255        |
# |    iterations         | 4200       |
# |    time_elapsed       | 82         |
# |    total_timesteps    | 21000      |
# | train/                |            |
# |    entropy_loss       | -1.35      |
# |    explained_variance | 0.0198     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4199       |
# |    policy_loss        | -12.5      |
# |    reward             | -0.8243504 |
# |    std                | 0.93       |
# |    value_loss         | 99.3       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 255         |
# |    iterations         | 4300        |
# |    time_elapsed       | 84          |
# |    total_timesteps    | 21500       |
# | train/                |             |
# |    entropy_loss       | -1.35       |
# |    explained_variance | -1.23       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4299        |
# |    policy_loss        | -0.671      |
# |    reward             | -0.33780894 |
# |    std                | 0.934       |
# |    value_loss         | 0.41        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 255       |
# |    iterations         | 4400      |
# |    time_elapsed       | 86        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -1.35     |
# |    explained_variance | -0.0251   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | 11.5      |
# |    reward             | -44.48083 |
# |    std                | 0.932     |
# |    value_loss         | 200       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 4500     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | -0.012   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 105      |
# |    reward             | 6.404189 |
# |    std                | 0.926    |
# |    value_loss         | 2.89e+03 |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 255         |
# |    iterations         | 4600        |
# |    time_elapsed       | 89          |
# |    total_timesteps    | 23000       |
# | train/                |             |
# |    entropy_loss       | -1.35       |
# |    explained_variance | -0.94       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4599        |
# |    policy_loss        | 0.792       |
# |    reward             | 0.009700734 |
# |    std                | 0.933       |
# |    value_loss         | 0.392       |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 4700     |
# |    time_elapsed       | 91       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | 0.0105   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 18.8     |
# |    reward             | 0.592545 |
# |    std                | 0.944    |
# |    value_loss         | 134      |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 255        |
# |    iterations         | 4800       |
# |    time_elapsed       | 93         |
# |    total_timesteps    | 24000      |
# | train/                |            |
# |    entropy_loss       | -1.37      |
# |    explained_variance | 0.0233     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4799       |
# |    policy_loss        | -5.44      |
# |    reward             | -1.1444132 |
# |    std                | 0.956      |
# |    value_loss         | 92.3       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 4900     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.0493   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.0939  |
# |    reward             | 0.613074 |
# |    std                | 0.953    |
# |    value_loss         | 0.0852   |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 256         |
# |    iterations         | 5000        |
# |    time_elapsed       | 97          |
# |    total_timesteps    | 25000       |
# | train/                |             |
# |    entropy_loss       | -1.37       |
# |    explained_variance | 0.000694    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4999        |
# |    policy_loss        | -3.17       |
# |    reward             | -0.47687483 |
# |    std                | 0.952       |
# |    value_loss         | 28.3        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 5100      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -1.37     |
# |    explained_variance | 0.0115    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | 11        |
# |    reward             | -6.570523 |
# |    std                | 0.954     |
# |    value_loss         | 203       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 5200      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -1.37     |
# |    explained_variance | -0.00213  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -0.896    |
# |    reward             | 0.1874071 |
# |    std                | 0.953     |
# |    value_loss         | 0.67      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 5300      |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -1.38     |
# |    explained_variance | 0.0013    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | 17.6      |
# |    reward             | 1.0518755 |
# |    std                | 0.961     |
# |    value_loss         | 274       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 256        |
# |    iterations         | 5400       |
# |    time_elapsed       | 105        |
# |    total_timesteps    | 27000      |
# | train/                |            |
# |    entropy_loss       | -1.39      |
# |    explained_variance | 0.0291     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5399       |
# |    policy_loss        | -22.3      |
# |    reward             | -3.6721048 |
# |    std                | 0.967      |
# |    value_loss         | 198        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 256         |
# |    iterations         | 5500        |
# |    time_elapsed       | 107         |
# |    total_timesteps    | 27500       |
# | train/                |             |
# |    entropy_loss       | -1.39       |
# |    explained_variance | 0.0799      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5499        |
# |    policy_loss        | -0.939      |
# |    reward             | -0.31073794 |
# |    std                | 0.969       |
# |    value_loss         | 0.199       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 5600      |
# |    time_elapsed       | 109       |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -1.39     |
# |    explained_variance | 0.00333   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | 7.4       |
# |    reward             | 4.7359476 |
# |    std                | 0.969     |
# |    value_loss         | 102       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 256        |
# |    iterations         | 5700       |
# |    time_elapsed       | 111        |
# |    total_timesteps    | 28500      |
# | train/                |            |
# |    entropy_loss       | -1.37      |
# |    explained_variance | 0.00123    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5699       |
# |    policy_loss        | 23.9       |
# |    reward             | -10.378523 |
# |    std                | 0.956      |
# |    value_loss         | 747        |
# --------------------------------------
# day: 1504, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 2333968.54
# total_reward: 1333968.54
# total_cost: 360472.43
# total_trades: 1498
# Sharpe: 0.594
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 256        |
# |    iterations         | 5800       |
# |    time_elapsed       | 113        |
# |    total_timesteps    | 29000      |
# | train/                |            |
# |    entropy_loss       | -1.37      |
# |    explained_variance | -0.407     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5799       |
# |    policy_loss        | -1.6       |
# |    reward             | -0.6220155 |
# |    std                | 0.955      |
# |    value_loss         | 1.25       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 256        |
# |    iterations         | 5900       |
# |    time_elapsed       | 114        |
# |    total_timesteps    | 29500      |
# | train/                |            |
# |    entropy_loss       | -1.38      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5899       |
# |    policy_loss        | -0.396     |
# |    reward             | -0.8333499 |
# |    std                | 0.958      |
# |    value_loss         | 5.6        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 256        |
# |    iterations         | 6000       |
# |    time_elapsed       | 116        |
# |    total_timesteps    | 30000      |
# | train/                |            |
# |    entropy_loss       | -1.38      |
# |    explained_variance | 0.00377    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5999       |
# |    policy_loss        | -4.23      |
# |    reward             | -3.5921528 |
# |    std                | 0.966      |
# |    value_loss         | 24.5       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 6100      |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -1.4      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -1.44     |
# |    reward             | -1.552507 |
# |    std                | 0.983     |
# |    value_loss         | 1.25      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 256        |
# |    iterations         | 6200       |
# |    time_elapsed       | 120        |
# |    total_timesteps    | 31000      |
# | train/                |            |
# |    entropy_loss       | -1.41      |
# |    explained_variance | -0.00274   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6199       |
# |    policy_loss        | -12.2      |
# |    reward             | -3.5736113 |
# |    std                | 0.991      |
# |    value_loss         | 743        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 6300      |
# |    time_elapsed       | 122       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -1.41     |
# |    explained_variance | -0.00418  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | -36       |
# |    reward             | 7.4632554 |
# |    std                | 0.991     |
# |    value_loss         | 4.61e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 6400      |
# |    time_elapsed       | 124       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -1.41     |
# |    explained_variance | -0.655    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | 1.11      |
# |    reward             | -0.246377 |
# |    std                | 0.994     |
# |    value_loss         | 0.471     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 257        |
# |    iterations         | 6500       |
# |    time_elapsed       | 126        |
# |    total_timesteps    | 32500      |
# | train/                |            |
# |    entropy_loss       | -1.41      |
# |    explained_variance | 0.118      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6499       |
# |    policy_loss        | 1.95       |
# |    reward             | -0.6055196 |
# |    std                | 0.987      |
# |    value_loss         | 36         |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 257        |
# |    iterations         | 6600       |
# |    time_elapsed       | 128        |
# |    total_timesteps    | 33000      |
# | train/                |            |
# |    entropy_loss       | -1.41      |
# |    explained_variance | -0.00169   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6599       |
# |    policy_loss        | -101       |
# |    reward             | -21.791542 |
# |    std                | 0.993      |
# |    value_loss         | 9.23e+03   |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 6700      |
# |    time_elapsed       | 130       |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -1.41     |
# |    explained_variance | 0.176     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -2.01     |
# |    reward             | 2.1825154 |
# |    std                | 0.992     |
# |    value_loss         | 3.56      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 257        |
# |    iterations         | 6800       |
# |    time_elapsed       | 132        |
# |    total_timesteps    | 34000      |
# | train/                |            |
# |    entropy_loss       | -1.41      |
# |    explained_variance | -0.0209    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6799       |
# |    policy_loss        | -14.5      |
# |    reward             | -3.3532488 |
# |    std                | 0.989      |
# |    value_loss         | 264        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 257        |
# |    iterations         | 6900       |
# |    time_elapsed       | 134        |
# |    total_timesteps    | 34500      |
# | train/                |            |
# |    entropy_loss       | -1.41      |
# |    explained_variance | -0.00284   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6899       |
# |    policy_loss        | 156        |
# |    reward             | -72.235855 |
# |    std                | 0.993      |
# |    value_loss         | 1.13e+04   |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 257         |
# |    iterations         | 7000        |
# |    time_elapsed       | 136         |
# |    total_timesteps    | 35000       |
# | train/                |             |
# |    entropy_loss       | -1.41       |
# |    explained_variance | -0.828      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6999        |
# |    policy_loss        | 2.53        |
# |    reward             | -0.12382873 |
# |    std                | 0.987       |
# |    value_loss         | 4.51        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 7100      |
# |    time_elapsed       | 137       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -1.42     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | 1.08      |
# |    reward             | 1.0800862 |
# |    std                | 0.997     |
# |    value_loss         | 0.655     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 7200     |
# |    time_elapsed       | 139      |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.0803   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | -11.6    |
# |    reward             | 2.770215 |
# |    std                | 0.992    |
# |    value_loss         | 152      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 7300      |
# |    time_elapsed       | 141       |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -1.43     |
# |    explained_variance | -0.354    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | 1.26      |
# |    reward             | 1.9053732 |
# |    std                | 1.01      |
# |    value_loss         | 1.75      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 257        |
# |    iterations         | 7400       |
# |    time_elapsed       | 143        |
# |    total_timesteps    | 37000      |
# | train/                |            |
# |    entropy_loss       | -1.43      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7399       |
# |    policy_loss        | -3.14      |
# |    reward             | 0.06625367 |
# |    std                | 1.01       |
# |    value_loss         | 11         |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 7500      |
# |    time_elapsed       | 145       |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | 0.00512   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7499      |
# |    policy_loss        | 18.3      |
# |    reward             | -3.525961 |
# |    std                | 1.02      |
# |    value_loss         | 249       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 257        |
# |    iterations         | 7600       |
# |    time_elapsed       | 147        |
# |    total_timesteps    | 38000      |
# | train/                |            |
# |    entropy_loss       | -1.44      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7599       |
# |    policy_loss        | -0.0594    |
# |    reward             | 0.13107009 |
# |    std                | 1.02       |
# |    value_loss         | 0.00319    |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 7700      |
# |    time_elapsed       | 149       |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -1.46     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -0.0366   |
# |    reward             | 1.4924386 |
# |    std                | 1.04      |
# |    value_loss         | 0.000602  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 7800     |
# |    time_elapsed       | 151      |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -1.45    |
# |    explained_variance | -0.0273  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | 37.8     |
# |    reward             | 4.37913  |
# |    std                | 1.04     |
# |    value_loss         | 421      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 7900     |
# |    time_elapsed       | 153      |
# |    total_timesteps    | 39500    |
# | train/                |          |
# |    entropy_loss       | -1.45    |
# |    explained_variance | -0.081   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7899     |
# |    policy_loss        | 1.02     |
# |    reward             | 0.212625 |
# |    std                | 1.04     |
# |    value_loss         | 1.87     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 8000     |
# |    time_elapsed       | 155      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -1.45    |
# |    explained_variance | -0.00593 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7999     |
# |    policy_loss        | -10.9    |
# |    reward             | 8.440102 |
# |    std                | 1.03     |
# |    value_loss         | 147      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 8100      |
# |    time_elapsed       | 157       |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -1.46     |
# |    explained_variance | -0.00987  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | 18.5      |
# |    reward             | 20.549109 |
# |    std                | 1.04      |
# |    value_loss         | 291       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 8200     |
# |    time_elapsed       | 159      |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -1.47    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | -0.0045  |
# |    reward             | 0.0      |
# |    std                | 1.05     |
# |    value_loss         | 1.27e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 8300      |
# |    time_elapsed       | 161       |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -1.48     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8299      |
# |    policy_loss        | 1.31      |
# |    reward             | 0.0       |
# |    std                | 1.06      |
# |    value_loss         | 0.949     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 8400     |
# |    time_elapsed       | 163      |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -1.49    |
# |    explained_variance | 0.041    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8399     |
# |    policy_loss        | -12.8    |
# |    reward             | 6.467769 |
# |    std                | 1.07     |
# |    value_loss         | 85       |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 8500     |
# |    time_elapsed       | 165      |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -1.49    |
# |    explained_variance | 0.237    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | -0.972   |
# |    reward             | 0.24969  |
# |    std                | 1.08     |
# |    value_loss         | 1.46     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 8600     |
# |    time_elapsed       | 167      |
# |    total_timesteps    | 43000    |
# | train/                |          |
# |    entropy_loss       | -1.49    |
# |    explained_variance | -0.0317  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8599     |
# |    policy_loss        | -23.6    |
# |    reward             | 36.31365 |
# |    std                | 1.07     |
# |    value_loss         | 577      |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 257        |
# |    iterations         | 8700       |
# |    time_elapsed       | 169        |
# |    total_timesteps    | 43500      |
# | train/                |            |
# |    entropy_loss       | -1.49      |
# |    explained_variance | -0.00162   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8699       |
# |    policy_loss        | 232        |
# |    reward             | -142.91806 |
# |    std                | 1.07       |
# |    value_loss         | 2.97e+04   |
# --------------------------------------
# day: 1504, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 14310810.80
# total_reward: 13310810.80
# total_cost: 84936.79
# total_trades: 1489
# Sharpe: 0.992
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 8800     |
# |    time_elapsed       | 171      |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -1.5     |
# |    explained_variance | -8.14    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8799     |
# |    policy_loss        | 0.118    |
# |    reward             | -0.16544 |
# |    std                | 1.09     |
# |    value_loss         | 0.036    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 8900      |
# |    time_elapsed       | 173       |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -1.5      |
# |    explained_variance | -0.0373   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | 34.7      |
# |    reward             | -7.561736 |
# |    std                | 1.08      |
# |    value_loss         | 826       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 9000     |
# |    time_elapsed       | 174      |
# |    total_timesteps    | 45000    |
# | train/                |          |
# |    entropy_loss       | -1.5     |
# |    explained_variance | -0.0119  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8999     |
# |    policy_loss        | 43.4     |
# |    reward             | 84.8255  |
# |    std                | 1.08     |
# |    value_loss         | 3.1e+03  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 9100     |
# |    time_elapsed       | 176      |
# |    total_timesteps    | 45500    |
# | train/                |          |
# |    entropy_loss       | -1.49    |
# |    explained_variance | -14.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9099     |
# |    policy_loss        | 0.0676   |
# |    reward             | 0.049248 |
# |    std                | 1.08     |
# |    value_loss         | 0.102    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 9200     |
# |    time_elapsed       | 178      |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -1.49    |
# |    explained_variance | -0.305   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9199     |
# |    policy_loss        | -1.39    |
# |    reward             | 3.47728  |
# |    std                | 1.07     |
# |    value_loss         | 9.46     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 9300     |
# |    time_elapsed       | 180      |
# |    total_timesteps    | 46500    |
# | train/                |          |
# |    entropy_loss       | -1.48    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9299     |
# |    policy_loss        | 50.4     |
# |    reward             | 13.1242  |
# |    std                | 1.06     |
# |    value_loss         | 2.19e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 9400     |
# |    time_elapsed       | 182      |
# |    total_timesteps    | 47000    |
# | train/                |          |
# |    entropy_loss       | -1.48    |
# |    explained_variance | 0.00412  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9399     |
# |    policy_loss        | 0.0207   |
# |    reward             | 0.233242 |
# |    std                | 1.06     |
# |    value_loss         | 0.179    |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 257        |
# |    iterations         | 9500       |
# |    time_elapsed       | 184        |
# |    total_timesteps    | 47500      |
# | train/                |            |
# |    entropy_loss       | -1.49      |
# |    explained_variance | 0.0232     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9499       |
# |    policy_loss        | 22.2       |
# |    reward             | -5.8700304 |
# |    std                | 1.07       |
# |    value_loss         | 194        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 9600      |
# |    time_elapsed       | 186       |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -1.48     |
# |    explained_variance | -3.58e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9599      |
# |    policy_loss        | 50.7      |
# |    reward             | 66.29102  |
# |    std                | 1.07      |
# |    value_loss         | 1.41e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 9700      |
# |    time_elapsed       | 188       |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -1.49     |
# |    explained_variance | -0.278    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9699      |
# |    policy_loss        | -0.646    |
# |    reward             | -0.217074 |
# |    std                | 1.07      |
# |    value_loss         | 0.35      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 9800     |
# |    time_elapsed       | 190      |
# |    total_timesteps    | 49000    |
# | train/                |          |
# |    entropy_loss       | -1.49    |
# |    explained_variance | -0.238   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9799     |
# |    policy_loss        | 4.57     |
# |    reward             | 3.786696 |
# |    std                | 1.07     |
# |    value_loss         | 19.5     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 9900      |
# |    time_elapsed       | 192       |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -1.49     |
# |    explained_variance | -0.012    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9899      |
# |    policy_loss        | -16.4     |
# |    reward             | 13.879424 |
# |    std                | 1.07      |
# |    value_loss         | 104       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 10000     |
# |    time_elapsed       | 194       |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -1.49     |
# |    explained_variance | -2.6      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9999      |
# |    policy_loss        | -0.401    |
# |    reward             | -0.328301 |
# |    std                | 1.07      |
# |    value_loss         | 0.312     |
# -------------------------------------

# %%
data_risk_indicator = processed_full[(processed_full.date<'2019-12-30') & (processed_full.date>='2014-01-01')]
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])

# %%
insample_risk_indicator.vix.describe()
# Out:
# count    1505.000000
# mean       14.961708
# std         4.045220
# min         9.140000
# 25%        12.290000
# 50%        13.950000
# 75%        16.490000
# max        40.740002
# Name: vix, dtype: float64

# %%
insample_risk_indicator.vix.quantile(0.996)
# Out:
# 30.408559844970696

# %%
insample_risk_indicator.turbulence.describe()
# Out:
# count    1505.000000
# mean        0.928695
# std         2.975403
# min         0.000000
# 25%         0.003600
# 50%         0.095465
# 75%         0.568596
# max        47.316742
# Name: turbulence, dtype: float64

# %%
insample_risk_indicator.turbulence.quantile(0.996)
# Out:
# 23.658840384059832

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)

# %%
trade.head()
# Out:
#          date  tic     open  ...  close_60_sma    vix  turbulence
# 0  2019-12-30  BTC  7303.95  ...   7827.233667  14.82    0.249586
# 1  2019-12-31  BTC  7374.61  ...   7794.521500  13.78    0.390196
# 2  2020-01-02  BTC  7161.51  ...   7723.829167  12.47    0.018801
# 3  2020-01-03  BTC  7169.70  ...   7686.106167  14.02    0.631633
# 4  2020-01-06  BTC  7354.22  ...   7585.279000  13.85    1.486921
#
# [5 rows x 18 columns]

# %%
df_account_value, df_actions = DRLAgent.DRL_prediction(
    model=trained_a2c, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
df_account_value.shape
# Out:
# (314, 2)

# %%
df_account_value.tail()
# Out:
#            date  account_value
# 309  2021-03-23   9.682493e+06
# 310  2021-03-24   9.677344e+06
# 311  2021-03-25   9.341911e+06
# 312  2021-03-26   9.165013e+06
# 313  2021-03-29   9.956894e+06

# %%
df_actions.tail()
# Out:
#            date actions
# 308  2021-03-22     [0]
# 309  2021-03-23     [0]
# 310  2021-03-24     [0]
# 311  2021-03-25     [0]
# 312  2021-03-26     [0]

# %%
print("==============Get Backtest Results===========")
now = datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
perf_stats_all.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return           5.324732
# Cumulative returns      8.956894
# Annual volatility       0.680932
# Sharpe ratio            3.061898
# Calmar ratio           22.022575
# Stability               0.872024
# Max drawdown           -0.241785
# Omega ratio             1.738747
# Sortino ratio           5.342604
# Skew                         NaN
# Kurtosis                     NaN
# Tail ratio              1.461456
# Daily value at risk    -0.077516
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (313, 8)
# Annual return          0.128488
# Cumulative returns     0.161995
# Annual volatility      0.336334
# Sharpe ratio           0.529864
# Calmar ratio           0.346457
# Stability              0.428201
# Max drawdown          -0.370862
# Omega ratio            1.117407
# Sortino ratio          0.730232
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.815244
# Daily value at risk   -0.041667
# dtype: float64

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (313, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-12-30</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-03-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>14</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>532.473%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>895.689%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>68.093%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>3.06</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>22.02</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.87</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-24.179%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.74</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>5.34</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.46</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-7.752%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>6.88</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.07</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>24.18</td>
#       <td>2020-02-13</td>
#       <td>2020-03-11</td>
#       <td>2020-04-27</td>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>22.75</td>
#       <td>2021-01-08</td>
#       <td>2021-01-28</td>
#       <td>2021-02-09</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>21.18</td>
#       <td>2021-02-22</td>
#       <td>2021-03-01</td>
#       <td>2021-03-12</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>17.10</td>
#       <td>2020-08-18</td>
#       <td>2020-09-24</td>
#       <td>2020-10-22</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>14.42</td>
#       <td>2020-05-08</td>
#       <td>2020-05-12</td>
#       <td>2020-06-02</td>
#       <td>18</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.83%</td>
#       <td>-13.82%</td>
#       <td>19.85%</td>
#     </tr>
#   </tbody>
# </table>
